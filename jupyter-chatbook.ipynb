# %% [markdown]
# Set your API-Keys inside jupyter-chatbook.nix

# %%
#% bash
echo OPENAI: $OPENAI_API_KEY
echo MISTRAL: $MISTRAL_API_KEY
echo PALM: $PALM_API_KEY
echo GEMINI: $GEMINI_API_KEY
echo DEEPL: $DEEPL_AUTH_KEY
echo WOLFRAM: $WOLFRAM_ALPHA_API_KEY

# %% [markdown]
# If valid API keys have not been set, try something like

# %%
%*ENV<OPENAI_API_KEY>='put-your-key-here'

# %% [markdown]
# If you inserted a valid OPENAI_API_KEY the following should work

# %%
#% openai
Randomly generate 3 dog names and 4 cat names.
